# %%
import pandas as pd
import numpy as np
from nba_api.stats.endpoints import playercareerstats, playerdashboardbyyearoveryear
from nba_api.stats.static import players
# Out:
# /Users/anthonychen/opt/anaconda3/lib/python3.8/site-packages/pandas/core/computation/expressions.py:20: UserWarning: Pandas requires version '2.7.3' or newer of 'numexpr' (version '2.7.1' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED

# %%
#Players who didn't play in the NBA, but got drafted
#2015: Nikola Milutinov
#2013: Livio Jean-Charles
#2007: Petteri Koponen
#2003: Mike Sweetney (Michael Sweetney)
#1999: Frederic Weis
#1992: Clarence Weatherspoon (Clar. Weatherspoon)
#1991: Steve Smith (Steven Smith)
#1986: Len Bias` 
#1984: Melvin Turpin (Mel Turpin)
#1982: Fat Lever (Lafayette Lever)
#1981: Danny Schayes  (Dolph Schayes) (Played 18 seasons?)
#1980: James Ray (Jamesearl Ray)
#1979: Dave Greenwood (David Greenwood)

players.find_players_by_full_name("Mike Sweetney")
# Out:
# []

# %%
# Input: A list of names
# Output: Player IDs for each name
def get_player_ids(names):
    player_ids = []
    
    for name in names:
        print(name)
        player_ids.append(players.find_players_by_full_name(name)[0]['id'])
        
    assert len(names) == len(player_ids), \
    "Someone is missing"
    return player_ids

# %%
# Create a list of names first
_2018 = ['Donte DiVincenzo', 'Lonnie Walker IV', 'Kevin Huerter', 'Josh Okogie', 'Grayson Allen', 'Chandler Hutchison', 'Aaron Holiday', 'Moritz Wagner', 'Moritz Wagner', 'Robert Williams', 'Jacob Evans', 'Omari Spellman']
_2017=["Markelle Fultz", "Lonzo Ball", "Jayson Tatum", "Josh Jackson", "De'Aaron Fox", "Jonathan Isaac", "Lauri Markkanen", "Frank Ntilikina", "Dennis Smith Jr.", "Zach Collins", "Malik Monk", "Luke Kennard", "Donovan Mitchell", "Bam Adebayo", "Justin Jackson", "Justin Patton", "D.J. Wilson", "T.J. Leaf", "John Collins", "Harry Giles", "Terrance Ferguson", "Jarrett Allen", "O.G. Anunoby", "Tyler Lydon", "Anzejs Pasecniks", "Caleb Swanigan", "Kyle Kuzma", "Tony Bradley", "Derrick White", "Josh Hart"]
_2016=["Ben Simmons", "Brandon Ingram", "Jaylen Brown", "Dragan Bender", "Kris Dunn", "Buddy Hield", "Jamal Murray", "Marquese Chriss", "Jakob Poeltl", "Thon Maker", "Domantas Sabonis", "Taurean Prince", "Georgios Papagiannis", "Denzel Valentine", "Juancho Hernangomez", "Guerschon Yabusele", "Wade Baldwin", "Henry Ellenson", "Malik Beasley", "Caris LeVert", "DeAndre' Bembry", "Malachi Richardson", "Ante Zizic", "Timothe Luwawu-Cabarrot", "Brice Johnson", "Furkan Korkmaz", "Pascal Siakam", "Skal Labissiere", "Dejounte Murray", "Damian Jones"]
#check 2015
_2015=["Karl-Anthony Towns", "D'Angelo Russell", "Jahlil Okafor", "Kristaps Porzingis", "Mario Hezonja", "Willie Cauley-Stein", "Emmanuel Mudiay", "Stanley Johnson", "Frank Kaminsky", "Justise Winslow", "Myles Turner", "Trey Lyles", "Devin Booker", "Cameron Payne", "Kelly Oubre Jr.", "Terry Rozier", "Rashad Vaughn", "Sam Dekker", "Jerian Grant", "Delon Wright", "Justin Anderson", "Bobby Portis", "Rondae Hollis-Jefferson", "Tyus Jones", "Jarell Martin", "Nikola Milutinov", "Larry Nance Jr.", "RJ Hunter", "Chris McCullough", "Kevon Looney"]
_2008=["Derrick Rose", "Michael Beasley", "O.J. Mayo", "Russell Westbrook", "Kevin Love", "Danilo Gallinari", "Eric Gordon", "Joe Alexander", "D.J. Augustin", "Brook Lopez", "Jerryd Bayless", "Jason Thompson", "Brandon Rush", "Anthony Randolph", "Robin Lopez", "Marreese Speights", "Roy Hibbert", "JaVale McGee", "JJ Hickson", "Alexis Ajinca", "Ryan Anderson", "Courtney Lee", "Kosta Koufos", "Serge Ibaka", "Nicolas Batum", "George Hill", "Darrell Arthur", "Donte Greene", "DJ White", "J.R. Giddens"]
_2009=["Blake Griffin", "Hasheem Thabeet", "James Harden", "Tyreke Evans", "Ricky Rubio", "Jonny Flynn", "Stephen Curry", "Jordan Hill", "DeMar DeRozan", "Brandon Jennings", "Terrence Williams", "Gerald Henderson", "Tyler Hansbrough", "Earl Clark", "Austin Daye", "James Johnson", "Jrue Holiday", "Ty Lawson", "Jeff Teague", "Eric Maynor", "Darren Collison", "Victor Claver", "Omri Casspi", "Byron Mullens", "Rodrigue Beaubois", "Taj Gibson", "DeMarre Carroll", "Wayne Ellington", "Toney Douglas", "Christian Eyenga"]
_2010=["John Wall", "Evan Turner", "Derrick Favors", "Wesley Johnson", "DeMarcus Cousins", "Ekpe Udoh", "Greg Monroe", "Al-Farouq Aminu", "Gordon Hayward", "Paul George", "Cole Aldrich", "Xavier Henry", "Ed Davis", "Patrick Patterson", "Larry Sanders", "Luke Babbitt", "Kevin Seraphin", "Eric Bledsoe", "Avery Bradley", "James Anderson", "Craig Brackins", "Elliot Williams", "Trevor Booker", "Damion James", "Dominique Jones", "Quincy Pondexter", "Jordan Crawford", "Greivis Vasquez", "Daniel Orton", "Lazar Hayward"]
_2011=["Kyrie Irving", "Derrick Williams", "Enes Freedom", "Tristan Thompson", "Jonas Valanciunas", "Jan Vesely", "Bismack Biyombo", "Brandon Knight", "Kemba Walker", "Jimmer Fredette", "Klay Thompson", "Alec Burks", "Markieff Morris", "Marcus Morris", "Kawhi Leonard", "Nikola Vucevic", "Iman Shumpert", "Chris Singleton", "Tobias Harris", "Donatas Motiejunas", "Nolan Smith", "Kenneth Faried", "Nikola Mirotic", "Reggie Jackson", "MarShon Brooks", "Jordan Hamilton", "JaJuan Johnson", "Norris Cole", "Cory Joseph", "Jimmy Butler"]

#get_player_ids(_1979)
# Call the function and get a list of IDs back to paste into the Google Sheet
#pd.DataFrame(np.array(get_player_ids(_1979))).to_csv('/Users/anthonychen/Downloads/nba_ids.csv')

# %%
players.find_players_by_full_name("knight")
# Out:
# [{'id': 1630547,
#   'full_name': 'James Bouknight',
#   'first_name': 'James',
#   'last_name': 'Bouknight',
#   'is_active': True},
#  {'id': 77290,
#   'full_name': 'Billy Knight',
#   'first_name': 'Billy',
#   'last_name': 'Knight',
#   'is_active': False},
#  {'id': 77287,
#   'full_name': 'Bob Knight',
#   'first_name': 'Bob',
#   'last_name': 'Knight',
#   'is_active': False},
#  {'id': 2688,
#   'full_name': 'Brandin Knight',
#   'first_name': 'Brandin',
#   'last_name': 'Knight',
#   'is_active': False},
#  {'id': 202688,
#   'full_name': 'Brandon Knight',
#   'first_name': 'Brandon',
#   'last_name': 'Knight',
#   'is_active': False},
#  {'id': 1510,
#   'full_name': 'Brevin Knight',
#   'first_name': 'Brevin',
#   'last_name': 'Knight',
#   'is_active': False},
#  {'id': 1630233,
#   'full_name': 'Nathan Knight',
#   'first_name': 'Nathan',
#   'last_name': 'Knight',
#   'is_active': True},
#  {'id': 1861,
#   'full_name': 'Negele Knight',
#   'first_name': 'Negele',
# ...

# %%
_1979.remove("Roy Hamilton")
_1979.append("Roylee Hamilton")
_1979.remove("Cliff Robinson")
_1979.append("Cliff T. Robinson")
_1979.remove("Larry Knight")
get_player_ids(_1979)
# Out:
# Magic Johnson
# David Greenwood
# Bill Cartwright
# Greg Kelser
# Sidney Moncrief
# James Bailey
# Vinnie Johnson
# Calvin Natt
# Larry Demic
# Jim Paxson
# Dudley Bradley
# Brad Holland
# Phil Hubbard
# Jim Spanarkel
# Lee Johnson
# Reggie King
# Wiley Peck
# Sly Williams
# Kyle Macy
# Roylee Hamilton
# Cliff T. Robinson
# [77142,
#  76881,
#  76362,
#  77239,
#  77626,
#  76085,
#  77167,
#  77691,
#  76553,
#  77818,
#  76231,
#  77040,
#  77071,
#  78222,
#  77158,
#  77273,
#  77827,
#  78570,
#  77438,
#  76928,
#  77986]

# %%
# How to use NBA API to retrieve basic stats for a player

# Nikola Jokić
career = playercareerstats.PlayerCareerStats(player_id='77986') 

# pandas data frames
career.get_data_frames()[0]
# Out:
#     PLAYER_ID SEASON_ID LEAGUE_ID     TEAM_ID TEAM_ABBREVIATION  PLAYER_AGE  \
# 0       77986   1979-80        00  1610612751               NJN        20.0
# 1       77986   1980-81        00  1610612751               NJN        21.0
# 2       77986   1981-82        00  1610612758               KCK        22.0
# 3       77986   1981-82        00  1610612739               CLE        22.0
# 4       77986   1981-82        00           0               TOT        22.0
# 5       77986   1982-83        00  1610612739               CLE        23.0
# 6       77986   1983-84        00  1610612739               CLE        24.0
# 7       77986   1984-85        00  1610612764               WAS        25.0
# 8       77986   1985-86        00  1610612764               WAS        26.0
# 9       77986   1986-87        00  1610612755               PHL        27.0
# 10      77986   1987-88        00  1610612755               PHL        28.0
# ...

# %%
career.get_data_frames()[0].columns
# Out:
# Index(['PLAYER_ID', 'SEASON_ID', 'LEAGUE_ID', 'TEAM_ID', 'TEAM_ABBREVIATION',
#        'PLAYER_AGE', 'GP', 'GS', 'MIN', 'FGM', 'FGA', 'FG_PCT', 'FG3M', 'FG3A',
#        'FG3_PCT', 'FTM', 'FTA', 'FT_PCT', 'OREB', 'DREB', 'REB', 'AST', 'STL',
#        'BLK', 'TOV', 'PF', 'PTS'],
#       dtype='object')

# %%
players.find_player_by_id(203081)['full_name']
# Out:
# 'Damian Lillard'

# %%
# How to use NBA API to retrieve advanced stats for a player

#Damian Lillard
advanced = playerdashboardbyyearoveryear.PlayerDashboardByYearOverYear(player_id=str(203081), measure_type_detailed= 'Advanced', season_type_playoffs='Regular Season', per_mode_detailed='Per Game')
advanced_df = advanced.get_data_frames()[1]
name = [players.find_player_by_id(203081)['full_name']]*len(advanced_df)
advanced_df.insert(0, 'full_name', name)
advanced_df
# Out:
#          full_name GROUP_SET GROUP_VALUE     TEAM_ID TEAM_ABBREVIATION  \
# 0   Damian Lillard   By Year     2022-23  1610612757               POR
# 1   Damian Lillard   By Year     2021-22  1610612757               POR
# 2   Damian Lillard   By Year     2020-21  1610612757               POR
# 3   Damian Lillard   By Year     2019-20  1610612757               POR
# 4   Damian Lillard   By Year     2018-19  1610612757               POR
# 5   Damian Lillard   By Year     2017-18  1610612757               POR
# 6   Damian Lillard   By Year     2016-17  1610612757               POR
# 7   Damian Lillard   By Year     2015-16  1610612757               POR
# 8   Damian Lillard   By Year     2014-15  1610612757               POR
# 9   Damian Lillard   By Year     2013-14  1610612757               POR
# 10  Damian Lillard   By Year     2012-13  1610612757               POR
#
#           MAX_GAME_DATE  GP   W   L  W_PCT  ...  E_USG_PCT_RANK  E_PACE_RANK  \
# ...

# %%
advanced.get_data_frames()[1].columns
# Out:
# Index(['GROUP_SET', 'GROUP_VALUE', 'TEAM_ID', 'TEAM_ABBREVIATION',
#        'MAX_GAME_DATE', 'GP', 'W', 'L', 'W_PCT', 'MIN', 'E_OFF_RATING',
#        'OFF_RATING', 'sp_work_OFF_RATING', 'E_DEF_RATING', 'DEF_RATING',
#        'sp_work_DEF_RATING', 'E_NET_RATING', 'NET_RATING',
#        'sp_work_NET_RATING', 'AST_PCT', 'AST_TO', 'AST_RATIO', 'OREB_PCT',
#        'DREB_PCT', 'REB_PCT', 'TM_TOV_PCT', 'E_TOV_PCT', 'EFG_PCT', 'TS_PCT',
#        'USG_PCT', 'E_USG_PCT', 'E_PACE', 'PACE', 'PACE_PER40', 'sp_work_PACE',
#        'PIE', 'POSS', 'FGM', 'FGA', 'FGM_PG', 'FGA_PG', 'FG_PCT', 'GP_RANK',
#        'W_RANK', 'L_RANK', 'W_PCT_RANK', 'MIN_RANK', 'E_OFF_RATING_RANK',
#        'OFF_RATING_RANK', 'sp_work_OFF_RATING_RANK', 'E_DEF_RATING_RANK',
#        'DEF_RATING_RANK', 'sp_work_DEF_RATING_RANK', 'E_NET_RATING_RANK',
#        'NET_RATING_RANK', 'sp_work_NET_RATING_RANK', 'AST_PCT_RANK',
#        'AST_TO_RANK', 'AST_RATIO_RANK', 'OREB_PCT_RANK', 'DREB_PCT_RANK',
# ...

# %% [markdown]
# # Get advanced stats per season per player

# %%
def get_advanced_by_season(id_list):
    
    advanced = playerdashboardbyyearoveryear.PlayerDashboardByYearOverYear(player_id=str(id_list[0]), measure_type_detailed= 'Advanced', season_type_playoffs='Regular Season', per_mode_detailed='Per Game')
    advanced_df = advanced.get_data_frames()[1]
    name = [players.find_player_by_id(id_list[0])['full_name']]*len(advanced_df)
    advanced_df.insert(0, 'full_name', name)
    
    for player_id in id_list:
        print(player_id)
        time.sleep(random.uniform(0,60))
        next_player = playerdashboardbyyearoveryear.PlayerDashboardByYearOverYear(player_id=str(player_id), measure_type_detailed= 'Advanced', season_type_playoffs='Regular Season', per_mode_detailed='Per Game')
        next_player_df = next_player.get_data_frames()[1]
        name = [players.find_player_by_id(player_id)['full_name']]*len(next_player_df)
        next_player_df.insert(0, 'full_name', name)
        
        advanced_df = pd.concat([advanced_df,next_player_df], axis=1)
        
    return advanced_df

# %%
_2018_ids_sub = [1629028,1628963,1628991,1629027,1628964,1628976,1629012,1628995,1628969,1628983,1628970,1629010,1629008,1628972,1629015,1628978,1629022,1628989,1629006,1628960,1628990,1628988,1629021,1629021,1629057,1628980,1629016]
#x_year_ids = []

_2018_df = get_advanced_by_season(_2018_ids_sub)
_2018_df
# Out:
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\urllib3\connectionpool.py:449, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     445         except BaseException as e:
#     446             # Remove the TypeError from the exception chain in
#     447             # Python 3 (including for exceptions like SystemExit).
#     448             # Otherwise it looks like a bug in the code.
# --> 449             six.raise_from(e, None)
#     450 except (SocketTimeout, BaseSSLError, SocketError) as e:
#
# File <string>:3, in raise_from(value, from_value)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\urllib3\connectionpool.py:444, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     443 try:
# ...

# %%
_2018_df.tail()
# Out:
#        full_name GROUP_SET GROUP_VALUE     TEAM_ID TEAM_ABBREVIATION  \
# 0  Deandre Ayton   By Year     2022-23  1610612756               PHX
# 1  Deandre Ayton   By Year     2021-22  1610612756               PHX
# 2  Deandre Ayton   By Year     2020-21  1610612756               PHX
# 3  Deandre Ayton   By Year     2019-20  1610612756               PHX
# 4  Deandre Ayton   By Year     2018-19  1610612756               PHX
#
#          MAX_GAME_DATE  GP   W   L  W_PCT  ...  E_USG_PCT_RANK  E_PACE_RANK  \
# 0  2023-04-02T00:00:00  65  34  31  0.523  ...               2            4
# 1  2022-04-08T00:00:00  58  46  12  0.793  ...               3            3
# 2  2021-05-11T00:00:00  69  48  21  0.696  ...               5            5
# 3  2020-08-13T00:00:00  38  20  18  0.526  ...               1            1
# 4  2019-03-30T00:00:00  71  17  54  0.239  ...               4            2
#
#    PACE_RANK  sp_work_PACE_RANK  PIE_RANK  FGM_RANK  FGA_RANK  FGM_PG_RANK  \
# ...

# %%
player_id_df = pd.read_csv('/Users/anthonychen/Downloads/Player_IDs.csv')
player_id_df.head()
# Out:
#       NBA ID    YEAR   Rk   Pk   Tm             Player         College  Yrs  \
# 0        NaN     NaN  NaN  NaN  NaN                NaN             NaN  NaN
# 1  1629028.0  2018.0  1.0  1.0  PHO      Deandre Ayton         Arizona    5
# 2  1628963.0  2018.0  2.0  2.0  SAC  Marvin Bagley III            Duke    5
# 3        NaN  2018.0  3.0  3.0  ATL        Luka Dončić             NaN    5
# 4  1628991.0  2018.0  4.0  4.0  MEM  Jaren Jackson Jr.  Michigan State    5
#
#      G     MP  ...    3P%    FT%  MP.1 PTS.1 TRB.1 AST.1    WS  WS/48  BPM  \
# 0  NaN    NaN  ...    NaN    NaN   NaN   NaN   NaN   NaN   NaN    NaN  NaN
# 1  296   9069  ...  0.263  0.752  30.6  16.7  10.5   1.7  30.4  0.161  1.2
# 2  199   4905  ...  0.283   0.67  24.6  13.2   7.3   0.9   8.8  0.086   -2
# 3  321  10996  ...  0.339  0.737  34.3  27.5   8.6     8  38.3  0.167  7.3
# 4  254   6909  ...  0.349  0.792  27.2    16   5.4   1.1  17.7  0.123  0.5
#
#    VORP
# 0   NaN
# 1   7.2
# 2     0
# 3  25.8
# 4   4.4
# ...

# %%
id_yr=player_id_df[['NBA ID', 'YEAR']]
#separate based on year, pull the ids in there

# %%
_2018 
player_ids = player_id_df['NBA ID'].values
player_ids = [int(x) for x in player_ids if ~np.isnan(x)]

advanced_stats_df = get_advanced_by_season(player_ids)
# Out:
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\urllib3\connectionpool.py:449, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     445         except BaseException as e:
#     446             # Remove the TypeError from the exception chain in
#     447             # Python 3 (including for exceptions like SystemExit).
#     448             # Otherwise it looks like a bug in the code.
# --> 449             six.raise_from(e, None)
#     450 except (SocketTimeout, BaseSSLError, SocketError) as e:
#
# File <string>:3, in raise_from(value, from_value)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\urllib3\connectionpool.py:444, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     443 try:
# ...
